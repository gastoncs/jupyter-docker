# %%
import yfinance as yf   
aapl= yf.Ticker("aapl")
aapl_historical = aapl.history(start="2024-09-17", end="2024-09-18", interval="5m")
aapl_historical.index
# Out:
# DatetimeIndex(['2024-09-17 09:30:00-04:00', '2024-09-17 09:35:00-04:00',
#                '2024-09-17 09:40:00-04:00', '2024-09-17 09:45:00-04:00',
#                '2024-09-17 09:50:00-04:00', '2024-09-17 09:55:00-04:00',
#                '2024-09-17 10:00:00-04:00', '2024-09-17 10:05:00-04:00',
#                '2024-09-17 10:10:00-04:00', '2024-09-17 10:15:00-04:00',
#                '2024-09-17 10:20:00-04:00', '2024-09-17 10:25:00-04:00',
#                '2024-09-17 10:30:00-04:00', '2024-09-17 10:35:00-04:00',
#                '2024-09-17 10:40:00-04:00', '2024-09-17 10:45:00-04:00',
#                '2024-09-17 10:50:00-04:00', '2024-09-17 10:55:00-04:00',
#                '2024-09-17 11:00:00-04:00', '2024-09-17 11:05:00-04:00',
#                '2024-09-17 11:10:00-04:00', '2024-09-17 11:15:00-04:00',
#                '2024-09-17 11:20:00-04:00', '2024-09-17 11:25:00-04:00',
#                '2024-09-17 11:30:00-04:00', '2024-09-17 11:35:00-04:00',
# ...
