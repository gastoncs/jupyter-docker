# %%
import pandas as pd
import pandas_ta as ta
import pandas as pd
import numpy as np
import plotly.graph_objects as go
from scipy import stats

df = pd.read_csv("data/EURUSD_Candlestick_1_Hour_BID_04.05.2003-15.04.2023.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173390 entries, 0 to 173389
# Data columns (total 6 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   Gmt time  173390 non-null  object
#  1   open      173390 non-null  float64
#  2   high      173390 non-null  float64
#  3   low       173390 non-null  float64
#  4   close     173390 non-null  float64
#  5   volume    173390 non-null  float64
# dtypes: float64(5), object(1)
# memory usage: 7.9+ MB
