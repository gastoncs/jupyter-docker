# %%
import sys
sys.path.append('../xtb')

import pandas as pd
import tables as tb
from DataCollectorXtb import DataCollectorXtb 
    
tb.file._open_files.close_all()

collector=DataCollectorXtb(symbol='AAPL.US_4', start='2024-01-01', end='2024-05-01', period='1h',
                spread_col=False, cols_to_save=['Date','Close'])


print(collector.data)
# Out:
# [2024-09-20 14:59:36,317][connect:74] Socket connected
# Max range for given period 1h is 6 months from now
# Start date is set to 2024-03-20
#                    Date   Close
# 0   2024-03-20 13:00:00  175.41
# 1   2024-03-20 14:00:00  175.63
# 2   2024-03-20 15:00:00  175.89
# 3   2024-03-20 16:00:00  176.41
# 4   2024-03-20 17:00:00  176.34
# ..                  ...     ...
# 198 2024-04-30 15:00:00  173.87
# 199 2024-04-30 16:00:00  173.59
# 200 2024-04-30 17:00:00  173.39
# 201 2024-04-30 18:00:00  172.86
# 202 2024-04-30 19:00:00  169.90
#
# [203 rows x 2 columns]
