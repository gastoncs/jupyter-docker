# %%
import sys
sys.path.append('../xtb')

import pandas as pd
import tables as tb
from DataCollectorXtb import DataCollectorXtb 
    
tb.file._open_files.close_all()

collector=DataCollectorXtb(symbol='NVDA.US_4', start='2024-10-28', end='2024-10-30', period='5min',
                spread_col=False)

print(collector.data)
# Out:
# [2024-10-31 08:33:30,570][connect:74] Socket connected
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 10
#       6 from DataCollectorXtb import DataCollectorXtb
#       8 tb.file._open_files.close_all()
# ---> 10 collector=DataCollectorXtb(symbol='NVDA.US_4', start='2024-10-28', end='2024-10-30', period='5min',
#      11                 spread_col=False)
#      13 print(collector.data)
#
# File ~/src/practice/old_test/../xtb/DataCollectorXtb.py:51, in DataCollectorXtb.__init__(self, symbol, start, end, period, cols_to_save, spread_col)
#      49 self.spread_col=spread_col
#      50 self.check_max_range()
# ---> 51 self.get_data()
#
# File ~/src/practice/old_test/../xtb/DataCollectorXtb.py:136, in DataCollectorXtb.get_data(self)
#     134 client.execute(loginCommand(user_id, pwd))
# ...
