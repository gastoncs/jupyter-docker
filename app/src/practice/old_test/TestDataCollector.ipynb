# %%
import sys
sys.path.append('../../xtb')

import pandas as pd
import tables as tb
from DataCollectorXtb import DataCollectorXtb 
    
tb.file._open_files.close_all()

collector=DataCollectorXtb(symbol='AAPL.US_4', start='2024-01-01', end='2024-05-01', period='1h',
                spread_col=False, cols_to_save=['Date','Close'])


print(collector.data)
# Out:
# [2024-10-23 15:17:12,483][connect:74] Socket connected
# Max range for given period 1h is 6 months from now
# Start date is set to 2024-04-23
#                   Date   Close
# 0  2024-04-23 13:00:00  165.39
# 1  2024-04-23 14:00:00  166.28
# 2  2024-04-23 15:00:00  166.30
# 3  2024-04-23 16:00:00  166.33
# 4  2024-04-23 17:00:00  166.26
# 5  2024-04-23 18:00:00  166.58
# 6  2024-04-23 19:00:00  166.72
# 7  2024-04-24 13:00:00  167.05
# 8  2024-04-24 14:00:00  167.44
# 9  2024-04-24 15:00:00  167.75
# 10 2024-04-24 16:00:00  168.07
# 11 2024-04-24 17:00:00  168.72
# 12 2024-04-24 18:00:00  168.18
# 13 2024-04-24 19:00:00  168.91
# 14 2024-04-25 13:00:00  169.20
# 15 2024-04-25 14:00:00  168.75
# 16 2024-04-25 15:00:00  168.19
# 17 2024-04-25 16:00:00  168.97
# 18 2024-04-25 17:00:00  169.05
# 19 2024-04-25 18:00:00  168.94
# 20 2024-04-25 19:00:00  169.33
# 21 2024-04-26 13:00:00  169.97
# 22 2024-04-26 14:00:00  170.52
# 23 2024-04-26 15:00:00  170.48
# ...
