# %%
from xAPIConnector import *
import config   

user_id = config.user_id
pwd= config.pwd

client=APIClient()
resp=client.execute(loginCommand(user_id, pwd))
ssid=resp['streamSessionId']

sclient=APIStreamClient(ssId=ssid, tickFun=procTickExample)
sclient.subscribePrice('EURUSD')

time.sleep(60)

sclient.unsubscribePrice('EURUSD')
time.sleep(5)
sclient.disconnect()
client.disconnect()
# Out:
# [2024-09-13 05:35:01,913][connect:74] Socket connected
# [2024-09-13 05:35:02,112][connect:74] Socket connected
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.10849, 'bid': 1.10841, 'high': 1.10898, 'low': 1.107, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1726205707880, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.10849, 'bid': 1.10841, 'high': 1.10898, 'low': 1.107, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1726205708591, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.10849, 'bid': 1.10841, 'high': 1.10898, 'low': 1.107, 'askVolume': 999000, 'bidVolume': 1000000, 'timestamp': 1726205709767, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.1085, 'bid': 1.10842, 'high': 1.10898, 'low': 1.107, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1726205710355, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.1085, 'bid': 1.10842, 'high': 1.10898, 'low': 1.107, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1726205711684, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.10851, 'bid': 1.10843, 'high': 1.10898, 'low': 1.107, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1726205719304, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.10851, 'bid': 1.10843, 'high': 1.10898, 'low': 1.107, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1726205733097, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.10849, 'bid': 1.10841, 'high': 1.10898, 'low': 1.107, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1726205734536, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.10848, 'bid': 1.1084, 'high': 1.10898, 'low': 1.107, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1726205738021, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.10846, 'bid': 1.10838, 'high': 1.10898, 'low': 1.107, 'askVolume': 997000, 'bidVolume': 1000000, 'timestamp': 1726205742369, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.10846, 'bid': 1.10838, 'high': 1.10898, 'low': 1.107, 'askVolume': 997000, 'bidVolume': 985000, 'timestamp': 1726205744197, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.10847, 'bid': 1.10839, 'high': 1.10898, 'low': 1.107, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1726205749258, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.10847, 'bid': 1.10839, 'high': 1.10898, 'low': 1.107, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1726205750006, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.10846, 'bid': 1.10838, 'high': 1.10898, 'low': 1.107, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1726205750212, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.10847, 'bid': 1.10839, 'high': 1.10898, 'low': 1.107, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1726205753145, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.10847, 'bid': 1.10839, 'high': 1.10898, 'low': 1.107, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1726205759583, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.10849, 'bid': 1.10841, 'high': 1.10898, 'low': 1.107, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1726205759813, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.10849, 'bid': 1.10841, 'high': 1.10898, 'low': 1.107, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1726205760079, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.1085, 'bid': 1.10842, 'high': 1.10898, 'low': 1.107, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1726205760283, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.1085, 'bid': 1.10842, 'high': 1.10898, 'low': 1.107, 'askVolume': 1000000, 'bidVolume': 998000, 'timestamp': 1726205761015, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.1085, 'bid': 1.10842, 'high': 1.10898, 'low': 1.107, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1726205762178, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
