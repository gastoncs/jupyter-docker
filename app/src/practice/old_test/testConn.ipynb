# %%
import sys
sys.path.append('../../xtb')

from xAPIConnector import *
import config   

user_id = config.user_id
pwd= config.pwd

client=APIClient()
resp=client.execute(loginCommand(user_id, pwd))
ssid=resp['streamSessionId']

sclient=APIStreamClient(ssId=ssid, tickFun=procTickExample)
sclient.subscribePrice('EURUSD')

time.sleep(60)

sclient.unsubscribePrice('EURUSD')
time.sleep(5)
sclient.disconnect()
client.disconnect()
# Out:
# [2024-10-23 15:22:31,582][connect:74] Socket connected
# [2024-10-23 15:22:31,806][connect:74] Socket connected
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.07826, 'bid': 1.07817, 'high': 1.08064, 'low': 1.07609, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1729696951943, 'level': 0, 'quoteId': 5, 'spreadTable': 0.9, 'spreadRaw': 9e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.07825, 'bid': 1.07817, 'high': 1.08064, 'low': 1.07609, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1729696952636, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.07825, 'bid': 1.07817, 'high': 1.08064, 'low': 1.07609, 'askVolume': 997000, 'bidVolume': 1000000, 'timestamp': 1729696953176, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.07824, 'bid': 1.07815, 'high': 1.08064, 'low': 1.07609, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1729696953791, 'level': 0, 'quoteId': 5, 'spreadTable': 0.9, 'spreadRaw': 9e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.07824, 'bid': 1.07815, 'high': 1.08064, 'low': 1.07609, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1729696954431, 'level': 0, 'quoteId': 5, 'spreadTable': 0.9, 'spreadRaw': 9e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.07823, 'bid': 1.07815, 'high': 1.08064, 'low': 1.07609, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1729696954909, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.07823, 'bid': 1.07814, 'high': 1.08064, 'low': 1.07609, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1729696955177, 'level': 0, 'quoteId': 5, 'spreadTable': 0.9, 'spreadRaw': 9e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.07823, 'bid': 1.07814, 'high': 1.08064, 'low': 1.07609, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1729696955468, 'level': 0, 'quoteId': 5, 'spreadTable': 0.9, 'spreadRaw': 9e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.07822, 'bid': 1.07814, 'high': 1.08064, 'low': 1.07609, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1729696955705, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.07823, 'bid': 1.07814, 'high': 1.08064, 'low': 1.07609, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1729696956081, 'level': 0, 'quoteId': 5, 'spreadTable': 0.9, 'spreadRaw': 9e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.07824, 'bid': 1.07815, 'high': 1.08064, 'low': 1.07609, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1729696956289, 'level': 0, 'quoteId': 5, 'spreadTable': 0.9, 'spreadRaw': 9e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.07823, 'bid': 1.07815, 'high': 1.08064, 'low': 1.07609, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1729696956580, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.07824, 'bid': 1.07815, 'high': 1.08064, 'low': 1.07609, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1729696956975, 'level': 0, 'quoteId': 5, 'spreadTable': 0.9, 'spreadRaw': 9e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.07823, 'bid': 1.07815, 'high': 1.08064, 'low': 1.07609, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1729696957846, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.07823, 'bid': 1.07815, 'high': 1.08064, 'low': 1.07609, 'askVolume': 1000000, 'bidVolume': 999000, 'timestamp': 1729696961238, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.07829, 'bid': 1.0782, 'high': 1.08064, 'low': 1.07609, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1729696963665, 'level': 0, 'quoteId': 5, 'spreadTable': 0.9, 'spreadRaw': 9e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.07829, 'bid': 1.07821, 'high': 1.08064, 'low': 1.07609, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1729696964419, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.07829, 'bid': 1.0782, 'high': 1.08064, 'low': 1.07609, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1729696965338, 'level': 0, 'quoteId': 5, 'spreadTable': 0.9, 'spreadRaw': 9e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.07829, 'bid': 1.07821, 'high': 1.08064, 'low': 1.07609, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1729696970280, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.07829, 'bid': 1.07821, 'high': 1.08064, 'low': 1.07609, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1729696970647, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.07829, 'bid': 1.07821, 'high': 1.08064, 'low': 1.07609, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1729696970936, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.07829, 'bid': 1.07821, 'high': 1.08064, 'low': 1.07609, 'askVolume': 950000, 'bidVolume': 1000000, 'timestamp': 1729696971158, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.07829, 'bid': 1.07821, 'high': 1.08064, 'low': 1.07609, 'askVolume': 949000, 'bidVolume': 1000000, 'timestamp': 1729696972755, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.07827, 'bid': 1.07818, 'high': 1.08064, 'low': 1.07609, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1729696973604, 'level': 0, 'quoteId': 5, 'spreadTable': 0.9, 'spreadRaw': 9e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.07826, 'bid': 1.07818, 'high': 1.08064, 'low': 1.07609, 'askVolume': 990000, 'bidVolume': 1000000, 'timestamp': 1729696975580, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.07827, 'bid': 1.07819, 'high': 1.08064, 'low': 1.07609, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1729696976017, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.07827, 'bid': 1.07818, 'high': 1.08064, 'low': 1.07609, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1729696976984, 'level': 0, 'quoteId': 5, 'spreadTable': 0.9, 'spreadRaw': 9e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.07827, 'bid': 1.07819, 'high': 1.08064, 'low': 1.07609, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1729696977233, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.07828, 'bid': 1.07819, 'high': 1.08064, 'low': 1.07609, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1729696979069, 'level': 0, 'quoteId': 5, 'spreadTable': 0.9, 'spreadRaw': 9e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.07827, 'bid': 1.07819, 'high': 1.08064, 'low': 1.07609, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1729696980116, 'level': 0, 'quoteId': 5, 'spreadTable': 0.8, 'spreadRaw': 8e-05}}
# TICK:  {'command': 'tickPrices', 'data': {'symbol': 'EURUSD', 'ask': 1.07828, 'bid': 1.07819, 'high': 1.08064, 'low': 1.07609, 'askVolume': 1000000, 'bidVolume': 1000000, 'timestamp': 1729696981269, 'level': 0, 'quoteId': 5, 'spreadTable': 0.9, 'spreadRaw': 9e-05}}
