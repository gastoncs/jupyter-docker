# %%
import sys
sys.path.append('../../xtb')

import pandas as pd
import tables as tb
from DataCollectorXtbV2 import DataCollectorXtbV2 as dataColl

#tb.file._open_files.close_all()

collector=dataColl(symbol='AAPL.US_4', start='2022-02-01', end='2023-02-01', period='1h', 
                   cols_to_save=['Date', 'Open','Close','High','Low'])

'''
store = pd.HDFStore("data/data.h5", "w")  
store.put("data", collector.data, format="table")  

data = store.select("/data")
data.to_csv('aapl.csv', index=False)

store.close()  
'''
collector
# Out:
# [2024-10-23 12:13:18,693][connect:74] Socket connected
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 10
#       6 from DataCollectorXtbV2 import DataCollectorXtbV2 as dataColl
#       8 #tb.file._open_files.close_all()
# ---> 10 collector=dataColl(symbol='AAPL.US_4', start='2022-02-01', end='2023-02-01', period='1h',
#      11                    cols_to_save=['Date', 'Open','Close','High','Low'])
#      13 '''
#      14 store = pd.HDFStore("data/data.h5", "w")
#      15 store.put("data", collector.data, format="table")
#    (...)
#      20 store.close()
#      21 '''
#      22 collector
#
# File ~/src/practice/../xtb/DataCollectorXtbV2.py:49, in DataCollectorXtbV2.__init__(self, symbol, start, end, period, cols_to_save, spread_col)
#      47 self.period = period
#      48 self.spread_col=spread_col
# ---> 49 self.get_data()
#
# ...
