# %%
import sys 
sys.path.append('../xtb')

import pandas as pd 
import tables as tb 
from DataCollectorXtbV2 import DataCollectorXtbV2 as dataColl

#tb.file._open_files.close_all()

collector=dataColl(symbol='AAPL.US_4', start='2024-10-28', end='2024-10-30', period='5min')

''' store = pd.HDFStore("data/data.h5", "w")
store.put("data", collector.data, format="table")

data = store.select("/data") data.to_csv('aapl.csv', index=False)

store.close()
'''
