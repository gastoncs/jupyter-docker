# %%
import sys
sys.path.append('../xtb')

import pandas as pd
import tables as tb
from DataCollectorXtbV2 import DataCollectorXtbV2 as dataColl

#tb.file._open_files.close_all()

collector=dataColl(symbol='AAPL.US_4', start='2022-02-01', end='2023-02-01', period='1h')

'''
store = pd.HDFStore("data/data.h5", "w")  
store.put("data", collector.data, format="table")  

data = store.select("/data")
data.to_csv('aapl.csv', index=False)

store.close()  
'''
collector
# Out:
# [2024-10-25 14:20:04,075][connect:74] Socket connected
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 10
#       6 from DataCollectorXtbV2 import DataCollectorXtbV2 as dataColl
#       8 #tb.file._open_files.close_all()
# ---> 10 collector=dataColl(symbol='AAPL.US_4', start='2022-02-01', end='2023-02-01', period='1h')
#      12 '''
#      13 store = pd.HDFStore("data/data.h5", "w")
#      14 store.put("data", collector.data, format="table")
#    (...)
#      19 store.close()
#      20 '''
#      21 collector
#
# File ~/src/practice/old_test/../xtb/DataCollectorXtbV2.py:49, in DataCollectorXtbV2.__init__(self, symbol, start, end, period, cols_to_save, spread_col)
#      47 self.period = period
#      48 self.spread_col=spread_col
# ---> 49 self.get_data()
#
# File ~/src/practice/old_test/../xtb/DataCollectorXtbV2.py:94, in DataCollectorXtbV2.get_data(self)
#      92 client.execute(loginCommand(user_id, pwd))
#      93 history_data = client.commandExecute('getChartRangeRequest', arguments=args)
# ---> 94 df = self.history_converter(history_data)
#      96 if self.cols_to_save==['Close'] or self.cols_to_save==['Close','vol']:
#      97     df=df.rename(columns={'Close':self.symbol})
#
# File ~/src/practice/old_test/../xtb/DataCollectorXtbV2.py:72, in DataCollectorXtbV2.history_converter(self, history)
#      68 df['Low'] = df['Open'] + df['low'] / (10 ** digits)
#      70 df.set_index("Date", inplace=True, drop=False)
# ---> 72 df = df[self.cols_to_save]
#      74 return df
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Vol'] not in index"
