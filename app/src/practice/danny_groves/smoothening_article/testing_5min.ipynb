# %%
import numpy as np
import pandas as pd

def explicit_heat_smooth(prices: np.array,
                         t_end: float = .50) -> np.array:
    '''
    Smoothen out a time series using a simple explicit finite difference method.
    The scheme uses a first-order method in time, and a second-order centred
    difference approximation in space. The scheme is only numerically stable
    if the time-step 0<=k<=1.
    
    The prices are fixed at the end-points, so the interior is smoothed.

    Parameters
    ----------
    prices : np.array
        The price to smoothen
    t_end : float
        The time at which to terminate the smootheing (i.e. t = 3)
        

    Returns
    -------
    P : np.array
        The smoothened time-series

    '''
    
    k = 0.1 # Time spacing
    
    # Set up the initial condition
    P = prices
    
    t = 0
    while t < t_end:
        # Solve the finite difference scheme for the next time-step
        P = k*(P[2:] + P[:-2]) + P[1:-1]*(1-2*k)
        
        # Add the fixed boundary conditions since the above solves the interior
        # points only
        P = np.hstack((
            np.array([prices[0]]),
            P,
            np.array([prices[-1]]),
        ))
        t += k

    return P

if __name__ == '__main__':

    df = pd.read_csv("../../data/MSFT.USUSD_Candlestick_5_M_BID_01.09.2022-21.09.2024.csv")
    df=df[0:1014]

    df.loc[:, 'close_smooth'] = explicit_heat_smooth(
        df['Close'].values, 
        t_end = 50
    )

    print(df)
    
    '''
    df.plot(
        y = ['Close', 'close_smooth'],
        xlabel = 'Date',
        ylabel = 'Price',
        title = 'TSLA Stock Price (Closing Prices)',
    ) 
    '''
# Out:
#                      Gmt time     Open     High      Low    Close  Volume  \
# 0     01.09.2022 00:00:00.000  261.326  261.326  261.326  261.326     0.0
# 1     01.09.2022 00:05:00.000  261.326  261.326  261.326  261.326     0.0
# 2     01.09.2022 00:10:00.000  261.326  261.326  261.326  261.326     0.0
# 3     01.09.2022 00:15:00.000  261.326  261.326  261.326  261.326     0.0
# 4     01.09.2022 00:20:00.000  261.326  261.326  261.326  261.326     0.0
# ...                       ...      ...      ...      ...      ...     ...
# 1009  04.09.2022 12:05:00.000  255.476  255.476  255.476  255.476     0.0
# 1010  04.09.2022 12:10:00.000  255.476  255.476  255.476  255.476     0.0
# 1011  04.09.2022 12:15:00.000  255.476  255.476  255.476  255.476     0.0
# 1012  04.09.2022 12:20:00.000  255.476  255.476  255.476  255.476     0.0
# 1013  04.09.2022 12:25:00.000  255.476  255.476  255.476  255.476     0.0
#
#       close_smooth
# 0          261.326
# 1          261.326
# 2          261.326
# 3          261.326
# 4          261.326
# ...            ...
# 1009       255.476
# 1010       255.476
# 1011       255.476
# 1012       255.476
# 1013       255.476
#
# [1014 rows x 7 columns]
