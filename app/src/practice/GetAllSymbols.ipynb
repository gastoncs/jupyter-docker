# %%
import sys
from pathlib import Path
base_path = Path("/home/jovyan/src")
xtb_dir = Path("xtb")
sys.path.append(str(base_path / xtb_dir))

import pandas as pd
import xAPIConnector
import config


user_id = config.user_id
pwd= config.pwd

client=xAPIConnector.APIClient()
resp=client.execute(xAPIConnector.loginCommand(user_id, pwd))
ssid=resp['streamSessionId']

all = client.execute({
	"command": "getAllSymbols"
})

data=pd.DataFrame(all['returnData'])
data.to_csv('allSymbols.csv', index=False)
# Out:
# [2024-11-03 22:07:29,990][connect:74] Socket connected
