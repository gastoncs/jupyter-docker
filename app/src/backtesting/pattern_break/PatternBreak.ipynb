# %%
import sys
sys.path.append('../../xtb')

from PatternBreakData import PatternBreakData
from PatternBreakStrategy import PatternBreakStrategy
from DataCollectorXtb import DataCollectorXtb

# %reload_ext autoreload
# %autoreload 2

refreshTable = False
smabt = PatternBreakData('AAPL.US_4', '2023-09-15', '2024-09-15', DataCollectorXtb, refreshTable) 
#print(smabt.data.info())

strategy = PatternBreakStrategy(smabt)
#strategy.plot_data()
print(strategy.check_for_long_market())

#smabt.data.to_csv('pattern.csv', index=False)
#smabt.run_strategy()
#smabt.plot_results()
# Out:
# 1
