# %%
# Create your connection.
cnx = sq3.connect('long_backtest_data.sql')
df = pd.read_sql_query("SELECT * FROM data", cnx)

result = round(df.groupby('symbol').agg(balance=('balance', 'max')),2)
result['gains'] = round(result-10000, 2)
result['percentage'] =  round((result['gains']/10000) * 100, 2)
result["balance"] = result["balance"].map("${:,.0f}".format)

df_summary = result.groupby(['symbol','balance','percentage'])['gains'].sum().sort_values(ascending=False)
df_summary.loc['Grand Total'] = df_summary.sum()
df_summary = df_summary.reset_index()

df_summary['gains'] = df_summary['gains'].map("${:,.0f}".format)
#df_summary['percentage'] = '${:,.2f}'.format(df_summary['percentage'], '.2f')

pd.set_option("display.max_columns", None) 
pd.set_option("display.max_rows", None) 

header = 'From: Oct-5 22 To:  Oct-5 24 <br> Inversion: $10,000 c/u <br> stop: close5minSmooth < ema25_5min <br> target: (buying_price-current_price) >= 2<br>'
styler = df_summary.style.set_caption(header).set_table_styles([{
    'selector': 'caption',
    'props': [
        ('color', 'Purple'),
        ('font-size', '15px'),
        ('font-style', 'italic'),
        ('font-weight', 'bold'),
        ('text-align', 'Left')
    ]
}])

display(styler)
# Out:
# <style type="text/css">
# #T_45fed caption {
#   color: Purple;
#   font-size: 15px;
#   font-style: italic;
#   font-weight: bold;
#   text-align: Left;
# }
# </style>
# <table id="T_45fed">
#   <caption>From: Oct-5 22 To:  Oct-5 24 <br> Inversion: $10,000 c/u <br> stop: close5minSmooth < ema25_5min <br> target: (buying_price-current_price) >= 2<br></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_45fed_level0_col0" class="col_heading level0 col0" >symbol</th>
#       <th id="T_45fed_level0_col1" class="col_heading level0 col1" >balance</th>
#       <th id="T_45fed_level0_col2" class="col_heading level0 col2" >percentage</th>
#       <th id="T_45fed_level0_col3" class="col_heading level0 col3" >gains</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45fed_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_45fed_row0_col0" class="data row0 col0" >AMD</td>
#       <td id="T_45fed_row0_col1" class="data row0 col1" >$26,405</td>
#       <td id="T_45fed_row0_col2" class="data row0 col2" >164.050000</td>
#       <td id="T_45fed_row0_col3" class="data row0 col3" >$16,405</td>
#     </tr>
#     <tr>
#       <th id="T_45fed_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_45fed_row1_col0" class="data row1 col0" >GOOGL</td>
#       <td id="T_45fed_row1_col1" class="data row1 col1" >$23,598</td>
#       <td id="T_45fed_row1_col2" class="data row1 col2" >135.980000</td>
#       <td id="T_45fed_row1_col3" class="data row1 col3" >$13,598</td>
#     </tr>
#     <tr>
#       <th id="T_45fed_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_45fed_row2_col0" class="data row2 col0" >NVDA</td>
#       <td id="T_45fed_row2_col1" class="data row2 col1" >$19,006</td>
#       <td id="T_45fed_row2_col2" class="data row2 col2" >90.060000</td>
#       <td id="T_45fed_row2_col3" class="data row2 col3" >$9,006</td>
#     </tr>
#     <tr>
#       <th id="T_45fed_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_45fed_row3_col0" class="data row3 col0" >AAPL</td>
#       <td id="T_45fed_row3_col1" class="data row3 col1" >$18,534</td>
#       <td id="T_45fed_row3_col2" class="data row3 col2" >85.340000</td>
#       <td id="T_45fed_row3_col3" class="data row3 col3" >$8,534</td>
#     </tr>
#     <tr>
#       <th id="T_45fed_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_45fed_row4_col0" class="data row4 col0" >TSLA</td>
#       <td id="T_45fed_row4_col1" class="data row4 col1" >$18,217</td>
#       <td id="T_45fed_row4_col2" class="data row4 col2" >82.170000</td>
#       <td id="T_45fed_row4_col3" class="data row4 col3" >$8,217</td>
#     </tr>
#     <tr>
#       <th id="T_45fed_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_45fed_row5_col0" class="data row5 col0" >FB</td>
#       <td id="T_45fed_row5_col1" class="data row5 col1" >$15,159</td>
#       <td id="T_45fed_row5_col2" class="data row5 col2" >51.590000</td>
#       <td id="T_45fed_row5_col3" class="data row5 col3" >$5,159</td>
#     </tr>
#     <tr>
#       <th id="T_45fed_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_45fed_row6_col0" class="data row6 col0" >QQQ</td>
#       <td id="T_45fed_row6_col1" class="data row6 col1" >$14,040</td>
#       <td id="T_45fed_row6_col2" class="data row6 col2" >40.400000</td>
#       <td id="T_45fed_row6_col3" class="data row6 col3" >$4,040</td>
#     </tr>
#     <tr>
#       <th id="T_45fed_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_45fed_row7_col0" class="data row7 col0" >SPY</td>
#       <td id="T_45fed_row7_col1" class="data row7 col1" >$13,689</td>
#       <td id="T_45fed_row7_col2" class="data row7 col2" >36.890000</td>
#       <td id="T_45fed_row7_col3" class="data row7 col3" >$3,689</td>
#     </tr>
#     <tr>
#       <th id="T_45fed_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_45fed_row8_col0" class="data row8 col0" >MSFT</td>
#       <td id="T_45fed_row8_col1" class="data row8 col1" >$12,982</td>
#       <td id="T_45fed_row8_col2" class="data row8 col2" >29.820000</td>
#       <td id="T_45fed_row8_col3" class="data row8 col3" >$2,982</td>
#     </tr>
#     <tr>
#       <th id="T_45fed_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_45fed_row9_col0" class="data row9 col0" >NFLX</td>
#       <td id="T_45fed_row9_col1" class="data row9 col1" >$12,477</td>
#       <td id="T_45fed_row9_col2" class="data row9 col2" >24.770000</td>
#       <td id="T_45fed_row9_col3" class="data row9 col3" >$2,477</td>
#     </tr>
#     <tr>
#       <th id="T_45fed_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_45fed_row10_col0" class="data row10 col0" >Grand Total</td>
#       <td id="T_45fed_row10_col1" class="data row10 col1" ></td>
#       <td id="T_45fed_row10_col2" class="data row10 col2" ></td>
#       <td id="T_45fed_row10_col3" class="data row10 col3" >$74,108</td>
#     </tr>
#   </tbody>
# </table>
