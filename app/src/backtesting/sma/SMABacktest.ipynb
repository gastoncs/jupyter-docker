# %%
import sys
sys.path.append('../xtb')

import SMAVectorBacktester as SMA
import pandas as pd
from DataCollectorXtb import DataCollectorXtb

smabt = SMA.SMAVectorBacktester('AAPL.US_4', 42, 252,'2010-1-1', '2019-12-31', DataCollectorXtb, False) 
#smabt.data.info()
#smabt.data
smabt.run_strategy()

#smabt.optimize_parameters((30, 50, 2),(200, 300, 2))
smabt.plot_results()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       5 import pandas as pd
#       6 from DataCollectorXtb import DataCollectorXtb
# ----> 8 smabt = SMA.SMAVectorBacktester('AAPL.US_4', 42, 252,'2010-1-1', '2019-12-31', False, DataCollectorXtb)
#       9 #smabt.data.info()
#      10 #smabt.data
#      11 smabt.run_strategy()
#
# File ~/src/back_testing/SMAVectorBacktester.py:57, in SMAVectorBacktester.__init__(self, symbol, SMA1, SMA2, start, end, dataCollector, refreshData)
#      55 self.dataCollector = dataCollector
#      56 self.refreshData = refreshData
# ---> 57 self.get_data()
#
# File ~/src/back_testing/SMAVectorBacktester.py:64, in SMAVectorBacktester.get_data(self)
#      61 ''' Retrieves and prepares the data.
#      62 '''
#      63 if(self.refreshData):
# ...
