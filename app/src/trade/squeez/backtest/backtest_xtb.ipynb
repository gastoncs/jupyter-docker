# %%
import sys
import pandas as pd 
import tables as tb 
from pathlib import Path

base_path = Path("/home/jovyan/src")
xtb_dir = Path("xtb")
sys.path.append(str(base_path / xtb_dir))
from DataCollectorXtbV3 import DataCollectorXtbV3 as dataColl

cwd = Path.cwd()
sys.path.append(str(cwd.parent))
import strategies

df=dataColl(symbol='AAPL.US_4', start='2024-10-28', end='2024-10-30', period='5min')
#result = strategies.squeez(df.data)
df.data
# Out:
# [2024-10-31 12:03:38,482][connect:74] Socket connected
#                        Open   Close    High     Low
# time
# 2024-10-28 13:45:00  233.02  233.35  234.10  232.96
# 2024-10-28 13:50:00  233.38  233.06  233.42  232.72
# 2024-10-28 13:55:00  233.19  232.95  233.19  232.80
# 2024-10-28 14:00:00  232.98  232.50  233.00  232.47
# 2024-10-28 14:05:00  232.51  232.27  232.61  232.20
# ...                     ...     ...     ...     ...
# 2024-10-29 19:35:00  233.67  233.80  233.83  233.65
# 2024-10-29 19:40:00  233.77  233.84  233.84  233.72
# 2024-10-29 19:45:00  233.83  233.85  233.89  233.78
# 2024-10-29 19:50:00  233.85  233.74  233.85  233.65
# 2024-10-29 19:55:00  233.75  233.87  233.88  233.70
#
# [150 rows x 4 columns]
